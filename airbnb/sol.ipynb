# %%
import pandas as pd

# %%
df = pd.read_csv('AB_NYC_2019.csv')

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
min_thresold, max_thresold = df.price.quantile([0.01, 0.999])
min_thresold, max_thresold
# Out:
# (30.0, 3000.0)

# %%
df[df.price < min_thresold]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 2860    1620248    Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# ...         ...                                              ...        ...
# 48486  36280646                     Cable and wfi, L/G included.  272872092
# 48647  36354776    Cozy bedroom in diverse neighborhood near JFK  273393150
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
df2 = df[(df.price < max_thresold) & (df.price > min_thresold)]
df2.shape
# Out:
# (48183, 16)

# %%
df2.sample(5)
# Out:
#              id                                               name    host_id  \
# 21902  17609502  5 minutes from JFK,one single cozy bedroom for...  119592255
# 22708  18375815  Spacious private room close St. Barnabas Hospital  127249880
# 41626  32362267  Duplex apartment near JFK,  LGA, train & the city    5592622
# 33954  26890649                                Bedstuy Puppet Cave  125059640
# 44572  34306797          Bright & Beautiful Park Slope One-Bedroom  258251034
#
#        host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 21902      Kevin              Queens             Jamaica  40.68073  -73.78354
# 22708       Emma               Bronx             Tremont  40.84647  -73.89299
# 41626  Christina              Queens             Astoria  40.75605  -73.91341
# 33954        Ben            Brooklyn  Bedford-Stuyvesant  40.69516  -73.93462
# 44572      Julie            Brooklyn         South Slope  40.66678  -73.98822
#
# ...

# %%
df2.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
# check null values
null_check = df2.isnull().sum()
null_check[null_check > 0]
# Out:
# name                   16
# host_name              20
# last_review          9871
# reviews_per_month    9871
# dtype: int64

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# plot outliers
import matplotlib.pyplot as plt
import seaborn as sns

# sns.boxplot(x=df2.price)

# bar plot
y = df2.price.value_counts()
# sns.barplot( x=df2.price, y=y)

# max  price
# Out:
# (10000, 0)
